# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from pre_process import final_data

# %%
os.getcwd()
one_level_up = os.path.dirname(os.getcwd())
df = final_data()
df
# Out:
#                       Datetime      Tweet Id  \
# 0    2022-03-30 12:50:04+00:00  1.510000e+18
# 1    2022-03-30 06:37:12+00:00  1.510000e+18
# 2    2022-03-30 04:40:11+00:00  1.510000e+18
# 3    2022-03-30 03:06:59+00:00  1.510000e+18
# 4    2022-03-30 03:04:24+00:00  1.510000e+18
# ..                         ...           ...
# 663  2022-02-07 15:30:56+00:00  1.490000e+18
# 664  2022-02-07 08:31:45+00:00  1.490000e+18
# 665  2022-02-07 07:59:27+00:00  1.490000e+18
# 666  2022-02-06 10:53:33+00:00  1.490000e+18
# 667  2022-02-06 09:18:06+00:00  1.490000e+18
#
#                                                   Text      Username  \
# 0    The MSME Sector is crucial for India’s economi...  narendramodi
# 1    Was happy to participate in the 5th BIMSTEC Su...  narendramodi
# 2                      Speaking at the BIMSTEC Summit.  narendramodi
# 3    Congratulations to the entire @KonkanRailway T...  narendramodi
# 4    The enthusiasm towards this year’s Pariksha Pe...  narendramodi
# ..                                                 ...           ...
# 663  City tour of Mathura. Many thanks to the peopl...    ptshrikant
# 664  Public relations in Mathura's Govind Ashram, K...    ptshrikant
# 665  Received the blessings of Pujya Didi Maa Sadhv...    ptshrikant
# 666  Public relations in the cities of Mathura, Pan...    ptshrikant
# 667  Swara Nightingale, Bharat Ratna respected #Lat...    ptshrikant
#
#                                                 tokens Party
# 0    [The, MSME, Sector, is, crucial, for, India’s,...   BJP
# 1    [Was, happy, to, participate, in, the, 5th, BI...   BJP
# 2                [Speaking, at, the, BIMSTEC, Summit.]   BJP
# 3    [Congratulations, to, the, entire, @KonkanRail...   BJP
# 4    [The, enthusiasm, towards, this, year’s, Parik...   BJP
# ..                                                 ...   ...
# 663  [City, tour, of, Mathura., Many, thanks, to, t...   BJP
# 664  [Public, relations, in, Mathura's, Govind, Ash...   BJP
# 665  [Received, the, blessings, of, Pujya, Didi, Ma...   BJP
# 666  [Public, relations, in, the, cities, of, Mathu...   BJP
# 667  [Swara, Nightingale,, Bharat, Ratna, respected...   BJP
#
# [668 rows x 6 columns]

# %%
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyser = SentimentIntensityAnalyzer()
df['sentiment_score'] = df['Text'].apply(analyser.polarity_scores)
compound_score = []
sentiment_score = list(df['sentiment_score'])

for i in range(len(df['sentiment_score'])):
    compound_score.append(sentiment_score[i]['compound'])
    
df['sentiment_score'] = compound_score
df
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# /usr/local/lib/python3.7/dist-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "
#                       Datetime      Tweet Id  \
# 0    2022-03-30 12:50:04+00:00  1.510000e+18
# 1    2022-03-30 06:37:12+00:00  1.510000e+18
# 2    2022-03-30 04:40:11+00:00  1.510000e+18
# 3    2022-03-30 03:06:59+00:00  1.510000e+18
# 4    2022-03-30 03:04:24+00:00  1.510000e+18
# ..                         ...           ...
# 663  2022-02-07 15:30:56+00:00  1.490000e+18
# 664  2022-02-07 08:31:45+00:00  1.490000e+18
# 665  2022-02-07 07:59:27+00:00  1.490000e+18
# 666  2022-02-06 10:53:33+00:00  1.490000e+18
# 667  2022-02-06 09:18:06+00:00  1.490000e+18
#
#                                                   Text      Username  \
# 0    The MSME Sector is crucial for India’s economi...  narendramodi
# 1    Was happy to participate in the 5th BIMSTEC Su...  narendramodi
# 2                      Speaking at the BIMSTEC Summit.  narendramodi
# 3    Congratulations to the entire @KonkanRailway T...  narendramodi
# 4    The enthusiasm towards this year’s Pariksha Pe...  narendramodi
# ..                                                 ...           ...
# 663  City tour of Mathura. Many thanks to the peopl...    ptshrikant
# 664  Public relations in Mathura's Govind Ashram, K...    ptshrikant
# 665  Received the blessings of Pujya Didi Maa Sadhv...    ptshrikant
# 666  Public relations in the cities of Mathura, Pan...    ptshrikant
# 667  Swara Nightingale, Bharat Ratna respected #Lat...    ptshrikant
#
#                                                 tokens Party  sentiment_score
# 0    [The, MSME, Sector, is, crucial, for, India’s,...   BJP           0.7650
# 1    [Was, happy, to, participate, in, the, 5th, BI...   BJP           0.9313
# 2                [Speaking, at, the, BIMSTEC, Summit.]   BJP           0.0000
# 3    [Congratulations, to, the, entire, @KonkanRail...   BJP           0.9042
# 4    [The, enthusiasm, towards, this, year’s, Parik...   BJP           0.8720
# ..                                                 ...   ...              ...
# 663  [City, tour, of, Mathura., Many, thanks, to, t...   BJP           0.9493
# 664  [Public, relations, in, Mathura's, Govind, Ash...   BJP           0.6908
# 665  [Received, the, blessings, of, Pujya, Didi, Ma...   BJP           0.5423
# 666  [Public, relations, in, the, cities, of, Mathu...   BJP           0.8442
# 667  [Swara, Nightingale,, Bharat, Ratna, respected...   BJP           0.6696
#
# [668 rows x 7 columns]

# %%
leaders = ['narendramodi','SwamiPMaurya','yadavakhilesh','shivpalsinghyad','AjayLalluINC','kpmaurya1','ptshrikant' ]

def sentiment_grouping(sentiment_compound):
    if sentiment_compound >= 0.05:
        return 'Positive'
    elif (sentiment_compound > -0.05 and sentiment_compound < 0.05):
        return 'Neutral'
    elif sentiment_compound <= -0.05:
        return 'Negative'

df['sentiment'] = df['sentiment_score'].apply(sentiment_grouping)
leader_df = df[df['Username'].isin(leaders)]
leader_df.groupby(['Username', 'sentiment']).count()['Party']
df
# Out:
#                       Datetime      Tweet Id  \
# 0    2022-03-30 12:50:04+00:00  1.510000e+18
# 1    2022-03-30 06:37:12+00:00  1.510000e+18
# 2    2022-03-30 04:40:11+00:00  1.510000e+18
# 3    2022-03-30 03:06:59+00:00  1.510000e+18
# 4    2022-03-30 03:04:24+00:00  1.510000e+18
# ..                         ...           ...
# 663  2022-02-07 15:30:56+00:00  1.490000e+18
# 664  2022-02-07 08:31:45+00:00  1.490000e+18
# 665  2022-02-07 07:59:27+00:00  1.490000e+18
# 666  2022-02-06 10:53:33+00:00  1.490000e+18
# 667  2022-02-06 09:18:06+00:00  1.490000e+18
#
#                                                   Text      Username  \
# 0    The MSME Sector is crucial for India’s economi...  narendramodi
# 1    Was happy to participate in the 5th BIMSTEC Su...  narendramodi
# 2                      Speaking at the BIMSTEC Summit.  narendramodi
# 3    Congratulations to the entire @KonkanRailway T...  narendramodi
# 4    The enthusiasm towards this year’s Pariksha Pe...  narendramodi
# ..                                                 ...           ...
# 663  City tour of Mathura. Many thanks to the peopl...    ptshrikant
# 664  Public relations in Mathura's Govind Ashram, K...    ptshrikant
# 665  Received the blessings of Pujya Didi Maa Sadhv...    ptshrikant
# 666  Public relations in the cities of Mathura, Pan...    ptshrikant
# 667  Swara Nightingale, Bharat Ratna respected #Lat...    ptshrikant
#
#                                                 tokens Party  sentiment_score  \
# 0    [The, MSME, Sector, is, crucial, for, India’s,...   BJP           0.7650
# 1    [Was, happy, to, participate, in, the, 5th, BI...   BJP           0.9313
# 2                [Speaking, at, the, BIMSTEC, Summit.]   BJP           0.0000
# 3    [Congratulations, to, the, entire, @KonkanRail...   BJP           0.9042
# 4    [The, enthusiasm, towards, this, year’s, Parik...   BJP           0.8720
# ..                                                 ...   ...              ...
# 663  [City, tour, of, Mathura., Many, thanks, to, t...   BJP           0.9493
# 664  [Public, relations, in, Mathura's, Govind, Ash...   BJP           0.6908
# 665  [Received, the, blessings, of, Pujya, Didi, Ma...   BJP           0.5423
# 666  [Public, relations, in, the, cities, of, Mathu...   BJP           0.8442
# 667  [Swara, Nightingale,, Bharat, Ratna, respected...   BJP           0.6696
#
#     sentiment
# 0    Positive
# 1    Positive
# 2     Neutral
# 3    Positive
# 4    Positive
# ..        ...
# 663  Positive
# 664  Positive
# 665  Positive
# 666  Positive
# 667  Positive
#
# [668 rows x 8 columns]

# %%
leader_sentiment  = leader_df.groupby(['Username', 'sentiment']).count()['Party'].reset_index()
leader_sentiment

leaders = ['narendramodi','SwamiPMaurya','yadavakhilesh','shivpalsinghyad','AjayLalluINC','kpmaurya1','ptshrikant' ]
leader_sentiment.columns  = ['Username','sentiment','num_count']

fig, ax = plt.subplots(2,4, figsize=(15,7))
plt.suptitle('Percentage of Leader Tweets according to Sentiment')
for i in range(ax.shape[0]):
    for j in range(ax.shape[1]):
        count = i*3 +j
        politican = leader_sentiment.Username.unique()
        number_count = leader_sentiment[leader_sentiment['Username'] == leaders[count]].num_count
        label =  leader_sentiment[leader_sentiment['Username'] ==leaders[count]].sentiment
        ax[i,j].pie(number_count, labels = label, autopct='%.1f%%' )
        ax[i,j].set_title(leaders[count])
plt.savefig(one_level_up + '\\report_graph\\sentiment_analysis')
